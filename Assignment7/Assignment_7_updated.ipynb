# %% [markdown]
# ** Assignment 7**
# =================
# Name : Nihar Kanungo Batch : 6:30 AM , Monday
#
# Background :
# ==========
# This is a Image Recognition program which makes use of the Cifar 10 preprocessed dataset . The Code uses one of the most popular Tensorflow API Keras to perform the operations .It's a supervised Computer Vision problem.  There are so many state of the Art models developed over the period of time. Every year new models win the Imagenet competition being better than the previous year's winner. While the approaches adopted by those networks share many of the similar concepts at the same time the architecture design was seen to have gone through a lot of change . Having said that the best Architecture model till date has found to be ENAS (Efficient Neural Architecture Search). This model was developed by a machine learning algorithm and it contains the direct and many skip connections from many previous layers .
#
# ENAS is a fast and inexpensive approach for automatic model design. ENAS constructs a large computational graph, where each subgraph represents a neural network architecture, hence forcing all architectures to share their parameters. A controller is trained with policy gradient to search for a subgraph that maximizes the expected reward on a validation set. Meanwhile a model corresponding to the selected subgraph is trained to minimize a canonical cross entropy loss. Sharing parameters among child models allows ENAS to deliver strong empirical performances, whilst using much fewer GPU-hours than existing automatic model design approaches, and notably, 1000x less expensive than standard Neural Architecture Search.
#
#
# Input
# =======
#
# 1) 60000 images (10 Class)
#
# 2) The Images are already segreegated as Train and Test Data with the respective target values
#
# Environment
#
# Development - Colab GPU , Jupyter Notebook Repository : Github
#
# Algorithm
# ===========
# Functional API Model
#
# Convolutional Neural Network (2D)
#
# Maxpooling
#
# Softmax Activation function
#
# loss Function : Categorical Crossentropy
#
# Optimizer=Adam, SGD
#
# Metrics=accuracy
#
# Batch Normalization
#
# Drop Out
#
# Image Normalization
#
# L2 Regularization
#
# Parameters
# ===========
#
# Batch Size - Variable
#
# Epochs - Variable
#
# Kernel Size - Variable
#
# Number of Kernels - Variable
#
# Learning Rate regularization coefficient
#
# Conditions
# ==========
# The Model should train (> 20% accuracy ). As this program is meant to show the usage of functional API and not to accurately predict the classes .

# %% [markdown]
# # Import all Libraries

# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D, DepthwiseConv2D, Conv2D, SeparableConv2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
from keras.layers import Input, concatenate
from keras.layers.pooling import GlobalAveragePooling2D
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import SGD, Nadam, Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, LearningRateScheduler
from keras.regularizers import l2
# %config InlineBackend.figure_format='retina'
from keras.models import Model
import tensorflow as tf
from keras.layers import Activation, Flatten, Dense, Dropout, Lambda
# Out:
# Using TensorFlow backend.

# %% [markdown]
# * Load the CIFAR 10 images into the notebook
# ===========================================
#
# The **CIFAR-10 dataset** (Canadian Institute For Advanced Research) is a collection of images that are commonly used to train machine learning and computer vision algorithms. It is one of the most widely used datasets for machine learning research. The CIFAR-10 dataset contains 60,000 32x32 color images in 10 different classes. The 10 different classes represent airplanes, cars, birds, cats, deer, dogs, frogs, horses, ships, and trucks. There are 6,000 images of each class.
# Computer algorithms for recognizing objects in photos often learn by example. CIFAR-10 is a set of images that can be used to teach a computer how to recognize objects. Since the images in CIFAR-10 are low-resolution (32x32), this dataset can allow researchers to quickly try different algorithms to see what works. Various kinds of convolutional neural networks tend to be the best at recognizing the images in CIFAR-10.
# CIFAR-10 is a labeled subset of the 80 million tiny images dataset. When the dataset was created, students were paid to label all of the images.
#
# Source : wikipedia

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 12s 0us/step

# %% [markdown]
# Display the Class outputs
# ===========================

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %% [markdown]
# Function to define the Model history and Plot chart
# =====================================================
# The Parameters of the model is a key information to quickly visualize how the model performed . Analysis of the
#
# 1. Training Accuracy vs Validation Accuracy and
#
# 2. Training Loss vs Validation Loss
#
# would give a great understanding of the model performance
#
# Writting a custom function helps us to modify or customize the information based on our need. We are building these functions so that we can customize more in future

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %% [markdown]
# # Function to define the Accuracy of the model
#
# This custom function will help us i future to design the Accuracy based on our need

# %%
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %% [markdown]
# Standardize the data by diving it by 255
# ==========================================

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %% [markdown]
# Each of the above discussed convolution methods has been designed as functions below . We may use multiple such layers in our network.

# %% [markdown]
# Normal convolution
# ===================
#
# This convolution is the one which we have been doing so far
#
# ![](images/nc.png)

# %%
def norm_conv_layer(inputs, n_kernels=32, kernel_size=(3,3), dropout=0.1,dilation_rate=1, border_mode='valid',stride=1):
  conv_out = Conv2D(n_kernels,
                kernel_size=kernel_size,
                strides=stride,
                border_mode=border_mode,
                kernel_regularizer=l2(1e-4),
                dilation_rate=dilation_rate)(inputs)
  conv_out = BatchNormalization()(conv_out)
  conv_out = Activation("relu")(conv_out)
  conv_out = Dropout(dropout)(conv_out)
  return conv_out

# %% [markdown]
# Depthwise Separable Convolution
# =======================
#
# Depthwise convolution deals with number of channels .Every channel will have different interpretations . Fir example if a layer of the network has 64 channels then there would be 64 different interpretation for it . All these can work in parallel. The diagram below explains it.
#
# ![](images/ds.png)

# %%
def depthwise_conv_layer(inputs, n_kernels=32, kernel_size=(3,3),dropout=0.1,dilation_rate=1, border_mode='valid', depth_multiplier=1,):
  dep_conv_out = SeparableConv2D(n_kernels,
                kernel_size=kernel_size,
                strides=1,
                border_mode=border_mode,
                kernel_regularizer=l2(1e-4),
                dilation_rate=dilation_rate,
                depth_multiplier=depth_multiplier,)(inputs)
  dep_conv_out = BatchNormalization()(dep_conv_out)
  dep_conv_out = Activation("relu")(dep_conv_out)
  dep_conv_out = Dropout(dropout)(dep_conv_out)
  return dep_conv_out

# %% [markdown]
# Transition Layer
# ==================
#
# 1 x 1 convolution

# %%
def trans_layer(inputs, n_kernels=32,dropout=0):
  trans_out = norm_conv_layer(inputs, n_kernels, kernel_size=(1,1),dropout=dropout, border_mode='same')
  return trans_out

# %% [markdown]
# # Output function
#
# 1. Flatten
#
# 2. Softmax layer

# %%
def output_layer(inputs, n_classes, kernel_size):
  final_out = Conv2D(n_classes,
                kernel_size=kernel_size,
                strides=1,
                border_mode='valid',
                kernel_regularizer=l2(1e-4),
                dilation_rate=1)(inputs)
  final_out = Flatten()(final_out)
  out = Activation("softmax")(final_out)
  return out

# %% [markdown]
# #Functional API model
#
# This Assignment is to create the ENAS model manually using the Keras API. The following table shows the different connections (direct and skip) for each layer .
#
# ![](images/enas.png)
# ![](images/model.png)
#
# The intention behind deploying the ENAs model manually is to have a hands on Functional API, Skip Connection and space to depth methodology.
#
#
# Model Architecture
# =====================
#
#
# After Every convolution there are Batch Normalization and Dropouts specified to ensure that the models don't over train
# L2 Regularizer is also added to ensure the model not being over trained

# %%
inputs = Input(shape=(32,32,3))

x1 = depthwise_conv_layer(inputs, n_kernels=64,kernel_size=(5,5),border_mode='valid')

x2 = norm_conv_layer(x1,n_kernels=64,kernel_size=(5,5),border_mode='same')  # 9

x3 = norm_conv_layer(x2,n_kernels=64,kernel_size=(5,5),border_mode='same')  #13

x4 = concatenate([x1, x3]) # 9,17
x4 = depthwise_conv_layer(x4, n_kernels=64,kernel_size=(5,5),border_mode='same')

x5 = MaxPooling2D(pool_size=(2, 2),)(x4)
x6 = depthwise_conv_layer(x5, n_kernels=64,kernel_size=(3,3),border_mode='same') 

x7_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x4)
x7_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x1)
x7 = concatenate([x6, x7_1, x7_2])
x7 = norm_conv_layer(x7, n_kernels=64,kernel_size=(5,5),border_mode='same')


x8_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x3)
x8_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x4)
x8 = concatenate([x6, x7,x8_1,x8_2])
x8 = depthwise_conv_layer(x8, n_kernels=64,kernel_size=(3,3),border_mode='same')


x9_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x1)
x9_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x3)
x9_3 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x4)
x9 = concatenate([x6,x7,x8,x9_1, x9_2,x9_3])
x9 = depthwise_conv_layer(x9, n_kernels=64,kernel_size=(3,3),border_mode='same')

x10_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x4)
x10 = concatenate([x6,x8,x9,x10_1])
x10 = MaxPooling2D(pool_size=(2, 2),)(x10)


#x11_1 = norm_conv_layer(x10, n_kernels=64,kernel_size=(5,5),border_mode='same')
x11_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x7)
x11 = concatenate([x10, x11_1])
x11 = norm_conv_layer(x11, n_kernels=64,kernel_size=(5,5),border_mode='same')


x12_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x8)
x12_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x2)
x12_3 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x4)
x12 = concatenate([x11, x12_1, x12_2,x12_3])
x12 = depthwise_conv_layer(x12, n_kernels=64,kernel_size=(5,5),border_mode='same')


x13_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x6)
x13_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x8)
x13_3 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x2)
x13 = concatenate([x11,x12,x13_1, x13_2,x13_3])
x13 = norm_conv_layer(x13, n_kernels=64,kernel_size=(3,3),border_mode='same')

x14_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x6)
x14_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x8)
x14_3 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x1)
x14_4 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x2)
x14_5 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x4)
x14 = concatenate([x12,x13,x14_1, x14_2,x14_3, x14_4, x14_5])
x14 = depthwise_conv_layer(x14, n_kernels=64,kernel_size=(5,5),border_mode='same')

x15_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x8)
x15_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x4)
x15 = concatenate([x12,x14,x15_1, x15_2])
output = output_layer(x15, n_classes=10, kernel_size=(7,7)) # 24, 32

model = Model(inputs=inputs, outputs=output)
optimizer = SGD(lr=0.001)
model.compile(loss='categorical_crossentropy',
             optimizer=optimizer,
             metrics=['accuracy'])
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0902 13:10:59.484985 139705983539072 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0902 13:10:59.521859 139705983539072 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(64, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, depth_multiplier=1, padding="valid")`
#
# W0902 13:10:59.531479 139705983539072 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0902 13:10:59.589519 139705983539072 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0902 13:10:59.590693 139705983539072 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0902 13:11:03.090594 139705983539072 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0902 13:11:03.263622 139705983539072 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(64, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, depth_multiplier=1, padding="same")`
#
# W0902 13:11:03.650887 139705983539072 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(64, kernel_size=(3, 3), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, depth_multiplier=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, kernel_size=(3, 3), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, kernel_size=(7, 7), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, padding="valid")`
#   import sys
# W0902 13:11:04.867439 139705983539072 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %% [markdown]
# # Print the summary of the model architecture

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# separable_conv2d_1 (SeparableCo (None, 28, 28, 64)   331         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 28, 28, 64)   256         separable_conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 28, 28, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 28, 28, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 28, 28, 64)   102464      dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 28, 28, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 28, 28, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 28, 28, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 28, 28, 64)   102464      dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 28, 28, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 28, 28, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 28, 28, 64)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 28, 28, 128)  0           dropout_1[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_2 (SeparableCo (None, 28, 28, 64)   11456       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 28, 28, 64)   256         separable_conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 28, 28, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 28, 28, 64)   0           activation_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 14, 14, 64)   0           dropout_4[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_3 (SeparableCo (None, 14, 14, 64)   4736        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 14, 14, 64)   256         separable_conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 14, 14, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 14, 14, 64)   0           activation_5[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 14, 14, 256)  0           dropout_4[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 14, 14, 256)  0           dropout_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 14, 14, 576)  0           dropout_5[0][0]
#                                                                  lambda_1[0][0]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 14, 14, 64)   921664      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 14, 14, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 14, 14, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 14, 14, 64)   0           activation_6[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 14, 14, 256)  0           dropout_3[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 14, 14, 256)  0           dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 14, 14, 640)  0           dropout_5[0][0]
#                                                                  dropout_6[0][0]
#                                                                  lambda_3[0][0]
#                                                                  lambda_4[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_4 (SeparableCo (None, 14, 14, 64)   46784       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 14, 14, 64)   256         separable_conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 14, 14, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 14, 14, 64)   0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 14, 14, 256)  0           dropout_1[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 14, 14, 256)  0           dropout_3[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 14, 14, 256)  0           dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 14, 14, 960)  0           dropout_5[0][0]
#                                                                  dropout_6[0][0]
#                                                                  dropout_7[0][0]
#                                                                  lambda_5[0][0]
#                                                                  lambda_6[0][0]
#                                                                  lambda_7[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_5 (SeparableCo (None, 14, 14, 64)   70144       concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 14, 14, 64)   256         separable_conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 14, 14, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 14, 14, 64)   0           activation_8[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 14, 14, 256)  0           dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 14, 14, 448)  0           dropout_5[0][0]
#                                                                  dropout_7[0][0]
#                                                                  dropout_8[0][0]
#                                                                  lambda_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 7, 7, 448)    0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 7, 7, 256)    0           dropout_6[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 7, 7, 704)    0           max_pooling2d_2[0][0]
#                                                                  lambda_9[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 7, 7, 64)     1126464     concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 7, 7, 64)     256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 7, 7, 64)     0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 7, 7, 64)     0           activation_9[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 7, 7, 256)    0           dropout_7[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 7, 7, 1024)   0           dropout_2[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 7, 7, 1024)   0           dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 7, 7, 2368)   0           dropout_9[0][0]
#                                                                  lambda_10[0][0]
#                                                                  lambda_11[0][0]
#                                                                  lambda_12[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_6 (SeparableCo (None, 7, 7, 64)     210816      concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 7, 7, 64)     256         separable_conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 7, 7, 64)     0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 7, 7, 64)     0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 7, 7, 256)    0           dropout_5[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 7, 7, 256)    0           dropout_7[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 7, 7, 1024)   0           dropout_2[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 7, 7, 1664)   0           dropout_9[0][0]
#                                                                  dropout_10[0][0]
#                                                                  lambda_13[0][0]
#                                                                  lambda_14[0][0]
#                                                                  lambda_15[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 7, 7, 64)     958528      concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 7, 7, 64)     256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 7, 7, 64)     0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 7, 7, 64)     0           activation_11[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 7, 7, 256)    0           dropout_5[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 7, 7, 256)    0           dropout_7[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 7, 7, 1024)   0           dropout_1[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 7, 7, 1024)   0           dropout_2[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 7, 7, 1024)   0           dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 7, 7, 3712)   0           dropout_10[0][0]
#                                                                  dropout_11[0][0]
#                                                                  lambda_16[0][0]
#                                                                  lambda_17[0][0]
#                                                                  lambda_18[0][0]
#                                                                  lambda_19[0][0]
#                                                                  lambda_20[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_7 (SeparableCo (None, 7, 7, 64)     330432      concatenate_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 7, 7, 64)     256         separable_conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 7, 7, 64)     0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 7, 7, 64)     0           activation_12[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 7, 7, 256)    0           dropout_7[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 7, 7, 1024)   0           dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 7, 7, 1408)   0           dropout_10[0][0]
#                                                                  dropout_12[0][0]
#                                                                  lambda_21[0][0]
#                                                                  lambda_22[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 1, 1, 10)     689930      concatenate_10[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 10)           0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 10)           0           flatten_1[0][0]
# ==================================================================================================
# Total params: 4,579,285
# Trainable params: 4,577,749
# Non-trainable params: 1,536
# __________________________________________________________________________________________________

# %% [markdown]
# # Model Training and Validation
#
# 1. Normalize the Images
#
# 2. Fit the images to the model
#
# 3. Calculate the time taken for training
#
# 4. Plot the model parameters
#
# 5. Print the last validation accuracy

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 50, 
                                 validation_data = (test_features, test_labels), verbose=1)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, steps_per_epoch=390, epochs=50)`
#   if sys.path[0] == '':
# Epoch 44/50
# 390/390 [==============================] - 144s 368ms/step - loss: 0.5300 - acc: 0.8436 - val_loss: 0.9732 - val_acc: 0.6889
# Epoch 45/50
# 390/390 [==============================] - 144s 369ms/step - loss: 0.5211 - acc: 0.8456 - val_loss: 0.9562 - val_acc: 0.6917
# Epoch 46/50
# 390/390 [==============================] - 144s 369ms/step - loss: 0.5214 - acc: 0.8449 - val_loss: 0.9295 - val_acc: 0.7022
# Epoch 47/50
# 390/390 [==============================] - 143s 367ms/step - loss: 0.5108 - acc: 0.8496 - val_loss: 0.9243 - val_acc: 0.7061
# Epoch 48/50
# 390/390 [==============================] - 143s 368ms/step - loss: 0.5005 - acc: 0.8541 - val_loss: 0.9516 - val_acc: 0.7011
# Epoch 49/50
# 390/390 [==============================] - 143s 367ms/step - loss: 0.4984 - acc: 0.8551 - val_loss: 0.9222 - val_acc: 0.7124
# Epoch 50/50
# 390/390 [==============================] - 143s 367ms/step - loss: 0.4940 - acc: 0.8574 - val_loss: 0.9145 - val_acc: 0.7119
# Model took 7182.09 seconds to train
# Accuracy on test data is: 71.19

# %% [markdown]
# Observation
# ===============
#
# If we observe the Accuracy curve then the training and validation curves hardly met each other in any iteration. This shows that the Validation is not smooth . The Possible reasons for this could be the hyper parameters which is not choosen correctly resulting in not converging to the minimum. The possible reason could be
#   1. vanishing gradient or
#   2. improper learning rate or
#   3. momentum
#
# The Loss curve is also not smooth for validation loss. The reason could be same . Also i am wondering if L2 regularization is having impact on the model being over trained as at times too much regularization causes the model to perform bad . We will try
#
# 1. removing L2 from the model and
# 2. Add transition blocks  to see how it performs .
#
#
# However before we do that I am just trying to run the model with different number of kernels . Let's see what the output looks like.

# %%
inputs = Input(shape=(32,32,3))

x1 = depthwise_conv_layer(inputs, n_kernels=64,kernel_size=(5,5),border_mode='valid')

x2 = norm_conv_layer(x1,n_kernels=64,kernel_size=(5,5),border_mode='same')  # 9

x3 = norm_conv_layer(x2,n_kernels=64,kernel_size=(5,5),border_mode='same')  #13

x4 = concatenate([x1, x3]) # 9,17
x4 = depthwise_conv_layer(x4, n_kernels=64,kernel_size=(5,5),border_mode='same')

x5 = MaxPooling2D(pool_size=(2, 2),)(x4)
x6 = depthwise_conv_layer(x5, n_kernels=128,kernel_size=(3,3),border_mode='same') 

x7_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x4)
x7_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x1)
x7 = concatenate([x6, x7_1, x7_2])
x7 = norm_conv_layer(x7, n_kernels=128,kernel_size=(5,5),border_mode='same')


x8_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x3)
x8_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x4)
x8 = concatenate([x6, x7,x8_1,x8_2])
x8 = depthwise_conv_layer(x8, n_kernels=128,kernel_size=(3,3),border_mode='same')


x9_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x1)
x9_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x3)
x9_3 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x4)
x9 = concatenate([x6,x7,x8,x9_1, x9_2,x9_3])
x9 = depthwise_conv_layer(x9, n_kernels=128,kernel_size=(5,5),border_mode='same')

x10_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x4)
x10 = concatenate([x6,x8,x9,x10_1])
x10 = MaxPooling2D(pool_size=(2, 2),)(x10)


#x11_1 = norm_conv_layer(x10, n_kernels=64,kernel_size=(5,5),border_mode='same')
x11_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x7)
x11 = concatenate([x10, x11_1])
x11 = norm_conv_layer(x11, n_kernels=256,kernel_size=(5,5),border_mode='same')


x12_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x8)
x12_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x2)
x12_3 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x4)
x12 = concatenate([x11, x12_1, x12_2,x12_3])
x12 = depthwise_conv_layer(x12, n_kernels=256,kernel_size=(5,5),border_mode='same')


x13_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x6)
x13_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x8)
x13_3 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x2)
x13 = concatenate([x11,x12,x13_1, x13_2,x13_3])
x13 = norm_conv_layer(x13, n_kernels=256,kernel_size=(3,3),border_mode='same')

x14_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x6)
x14_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x8)
x14_3 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x1)
x14_4 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x2)
x14_5 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x4)
x14 = concatenate([x12,x13,x14_1, x14_2,x14_3, x14_4, x14_5])
x14 = depthwise_conv_layer(x14, n_kernels=256,kernel_size=(5,5),border_mode='same')

x15_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x8)
x15_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x4)
x15 = concatenate([x12,x14,x15_1, x15_2])
output = output_layer(x15, n_classes=10, kernel_size=(7,7)) # 24, 32

model = Model(inputs=inputs, outputs=output)
optimizer = SGD(lr=0.001)
model.compile(loss='categorical_crossentropy',
             optimizer=optimizer,
             metrics=['accuracy'])


model.summary()

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 50, 
                                 validation_data = (test_features, test_labels), verbose=1)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0903 12:20:15.644129 140052710381440 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0903 12:20:15.683581 140052710381440 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(64, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, depth_multiplier=1, padding="valid")`
#
# W0903 12:20:15.692169 140052710381440 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0903 12:20:15.750019 140052710381440 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0903 12:20:15.751490 140052710381440 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0903 12:20:19.407734 140052710381440 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0903 12:20:19.579927 140052710381440 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(64, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, depth_multiplier=1, padding="same")`
#
# W0903 12:20:19.973207 140052710381440 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(128, kernel_size=(3, 3), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, depth_multiplier=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(128, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, depth_multiplier=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(256, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, depth_multiplier=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, kernel_size=(3, 3), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, kernel_size=(7, 7), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, padding="valid")`
#   import sys
# W0903 12:20:21.187239 140052710381440 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:88: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:88: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, steps_per_epoch=390, epochs=50)`
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# separable_conv2d_1 (SeparableCo (None, 28, 28, 64)   331         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 28, 28, 64)   256         separable_conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 28, 28, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 28, 28, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 28, 28, 64)   102464      dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 28, 28, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 28, 28, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 28, 28, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 28, 28, 64)   102464      dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 28, 28, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 28, 28, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 28, 28, 64)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 28, 28, 128)  0           dropout_1[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_2 (SeparableCo (None, 28, 28, 64)   11456       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 28, 28, 64)   256         separable_conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 28, 28, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 28, 28, 64)   0           activation_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 14, 14, 64)   0           dropout_4[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_3 (SeparableCo (None, 14, 14, 128)  8896        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 14, 14, 128)  512         separable_conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 14, 14, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 14, 14, 128)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 14, 14, 256)  0           dropout_4[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 14, 14, 256)  0           dropout_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 14, 14, 640)  0           dropout_5[0][0]
#                                                                  lambda_1[0][0]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 14, 14, 128)  2048128     concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 14, 14, 128)  512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 14, 14, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 14, 14, 128)  0           activation_6[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 14, 14, 256)  0           dropout_3[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 14, 14, 256)  0           dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 14, 14, 768)  0           dropout_5[0][0]
#                                                                  dropout_6[0][0]
#                                                                  lambda_3[0][0]
#                                                                  lambda_4[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_4 (SeparableCo (None, 14, 14, 128)  105344      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 14, 14, 128)  512         separable_conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 14, 14, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 14, 14, 128)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 14, 14, 256)  0           dropout_1[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 14, 14, 256)  0           dropout_3[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 14, 14, 256)  0           dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 14, 14, 1152) 0           dropout_5[0][0]
#                                                                  dropout_6[0][0]
#                                                                  dropout_7[0][0]
#                                                                  lambda_5[0][0]
#                                                                  lambda_6[0][0]
#                                                                  lambda_7[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_5 (SeparableCo (None, 14, 14, 128)  176384      concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 14, 14, 128)  512         separable_conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 14, 14, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 14, 14, 128)  0           activation_8[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 14, 14, 256)  0           dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 14, 14, 640)  0           dropout_5[0][0]
#                                                                  dropout_7[0][0]
#                                                                  dropout_8[0][0]
#                                                                  lambda_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 7, 7, 640)    0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 7, 7, 512)    0           dropout_6[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 7, 7, 1152)   0           max_pooling2d_2[0][0]
#                                                                  lambda_9[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 7, 7, 256)    7373056     concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 7, 7, 256)    1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 7, 7, 256)    0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 7, 7, 256)    0           activation_9[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 7, 7, 512)    0           dropout_7[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 7, 7, 1024)   0           dropout_2[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 7, 7, 1024)   0           dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 7, 7, 2816)   0           dropout_9[0][0]
#                                                                  lambda_10[0][0]
#                                                                  lambda_11[0][0]
#                                                                  lambda_12[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_6 (SeparableCo (None, 7, 7, 256)    791552      concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 7, 7, 256)    1024        separable_conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 7, 7, 256)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 7, 7, 256)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 7, 7, 512)    0           dropout_5[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 7, 7, 512)    0           dropout_7[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 7, 7, 1024)   0           dropout_2[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 7, 7, 2560)   0           dropout_9[0][0]
#                                                                  dropout_10[0][0]
#                                                                  lambda_13[0][0]
#                                                                  lambda_14[0][0]
#                                                                  lambda_15[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 7, 7, 256)    5898496     concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 7, 7, 256)    1024        conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 7, 7, 256)    0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 7, 7, 256)    0           activation_11[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 7, 7, 512)    0           dropout_5[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 7, 7, 512)    0           dropout_7[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 7, 7, 1024)   0           dropout_1[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 7, 7, 1024)   0           dropout_2[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 7, 7, 1024)   0           dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 7, 7, 4608)   0           dropout_10[0][0]
#                                                                  dropout_11[0][0]
#                                                                  lambda_16[0][0]
#                                                                  lambda_17[0][0]
#                                                                  lambda_18[0][0]
#                                                                  lambda_19[0][0]
#                                                                  lambda_20[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_7 (SeparableCo (None, 7, 7, 256)    1295104     concatenate_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 7, 7, 256)    1024        separable_conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 7, 7, 256)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 7, 7, 256)    0           activation_12[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 7, 7, 512)    0           dropout_7[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 7, 7, 1024)   0           dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 7, 7, 2048)   0           dropout_10[0][0]
#                                                                  dropout_12[0][0]
#                                                                  lambda_21[0][0]
#                                                                  lambda_22[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 1, 1, 10)     1003530     concatenate_10[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 10)           0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 10)           0           flatten_1[0][0]
# ==================================================================================================
# Total params: 18,924,373
# Trainable params: 18,920,789
# Non-trainable params: 3,584
# __________________________________________________________________________________________________
# W0903 12:20:21.468185 140052710381440 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/50
# 390/390 [==============================] - 241s 618ms/step - loss: 1.8990 - acc: 0.3686 - val_loss: 1.6892 - val_acc: 0.4424
# Epoch 2/50
# 390/390 [==============================] - 227s 582ms/step - loss: 1.6023 - acc: 0.4736 - val_loss: 1.5180 - val_acc: 0.5002
# Epoch 3/50
# 390/390 [==============================] - 227s 582ms/step - loss: 1.4592 - acc: 0.5260 - val_loss: 1.4333 - val_acc: 0.5379
# Epoch 4/50
# 390/390 [==============================] - 226s 580ms/step - loss: 1.3618 - acc: 0.5632 - val_loss: 1.4073 - val_acc: 0.5387
# Epoch 5/50
# 390/390 [==============================] - 226s 580ms/step - loss: 1.2883 - acc: 0.5942 - val_loss: 1.3626 - val_acc: 0.5684
# Epoch 6/50
# 390/390 [==============================] - 226s 580ms/step - loss: 1.2271 - acc: 0.6120 - val_loss: 1.4244 - val_acc: 0.5491
# Epoch 7/50
# 390/390 [==============================] - 227s 582ms/step - loss: 1.1746 - acc: 0.6319 - val_loss: 1.2939 - val_acc: 0.5913
# Epoch 8/50
# 390/390 [==============================] - 227s 583ms/step - loss: 1.1325 - acc: 0.6497 - val_loss: 1.3093 - val_acc: 0.5839
# Epoch 9/50
# 390/390 [==============================] - 227s 583ms/step - loss: 1.0857 - acc: 0.6668 - val_loss: 1.2087 - val_acc: 0.6228
# Epoch 10/50
# 390/390 [==============================] - 227s 583ms/step - loss: 1.0567 - acc: 0.6760 - val_loss: 1.2733 - val_acc: 0.6046
# Epoch 11/50
# 390/390 [==============================] - 227s 582ms/step - loss: 1.0239 - acc: 0.6887 - val_loss: 1.1999 - val_acc: 0.6313
# 390/390 [==============================] - 228s 584ms/step - loss: 0.6476 - acc: 0.8288 - val_loss: 0.9987 - val_acc: 0.7019
# Epoch 33/50
# 390/390 [==============================] - 227s 582ms/step - loss: 0.6391 - acc: 0.8310 - val_loss: 1.0169 - val_acc: 0.7011
# Epoch 34/50
# 390/390 [==============================] - 226s 580ms/step - loss: 0.6265 - acc: 0.8358 - val_loss: 1.0530 - val_acc: 0.6895
# Epoch 35/50
# 390/390 [==============================] - 226s 580ms/step - loss: 0.6177 - acc: 0.8400 - val_loss: 1.0169 - val_acc: 0.7023
# Epoch 36/50
# 390/390 [==============================] - 227s 582ms/step - loss: 0.6069 - acc: 0.8427 - val_loss: 1.0140 - val_acc: 0.6995
# Epoch 37/50
# 390/390 [==============================] - 228s 585ms/step - loss: 0.5951 - acc: 0.8472 - val_loss: 1.0254 - val_acc: 0.6977
# Epoch 38/50
# 390/390 [==============================] - 228s 585ms/step - loss: 0.5842 - acc: 0.8522 - val_loss: 1.0299 - val_acc: 0.6949
# Epoch 39/50
# 390/390 [==============================] - 228s 585ms/step - loss: 0.5785 - acc: 0.8546 - val_loss: 1.0004 - val_acc: 0.7072
# Epoch 40/50
# 390/390 [==============================] - 228s 584ms/step - loss: 0.5689 - acc: 0.8583 - val_loss: 1.0003 - val_acc: 0.7072
# Epoch 41/50
# 390/390 [==============================] - 228s 584ms/step - loss: 0.5614 - acc: 0.8620 - val_loss: 1.0185 - val_acc: 0.7037
# Epoch 42/50
# 390/390 [==============================] - 228s 583ms/step - loss: 0.5515 - acc: 0.8644 - val_loss: 1.0058 - val_acc: 0.7048
# Epoch 43/50
# 390/390 [==============================] - 227s 583ms/step - loss: 0.5432 - acc: 0.8679 - val_loss: 1.0203 - val_acc: 0.7062
# Epoch 44/50
# 390/390 [==============================] - 228s 583ms/step - loss: 0.5368 - acc: 0.8708 - val_loss: 1.0537 - val_acc: 0.6947
# Epoch 45/50
# 390/390 [==============================] - 227s 583ms/step - loss: 0.5306 - acc: 0.8721 - val_loss: 0.9811 - val_acc: 0.7148
# Epoch 46/50
# 390/390 [==============================] - 228s 584ms/step - loss: 0.5175 - acc: 0.8776 - val_loss: 1.0337 - val_acc: 0.7016
# Epoch 47/50
# 390/390 [==============================] - 228s 585ms/step - loss: 0.5116 - acc: 0.8793 - val_loss: 0.9987 - val_acc: 0.7139
# Epoch 48/50
# 390/390 [==============================] - 227s 581ms/step - loss: 0.5036 - acc: 0.8831 - val_loss: 0.9730 - val_acc: 0.7172
# Epoch 49/50
# 390/390 [==============================] - 227s 583ms/step - loss: 0.5006 - acc: 0.8841 - val_loss: 0.9713 - val_acc: 0.7190
# Epoch 50/50
# 390/390 [==============================] - 227s 582ms/step - loss: 0.4907 - acc: 0.8875 - val_loss: 0.9781 - val_acc: 0.7197
# Model took 11376.50 seconds to train
# Accuracy on test data is: 71.97

# %%
inputs = Input(shape=(32,32,3))

x1 = depthwise_conv_layer(inputs, n_kernels=64,kernel_size=(5,5),border_mode='valid')

x2 = norm_conv_layer(x1,n_kernels=64,kernel_size=(5,5),border_mode='same')  # 9

x3 = norm_conv_layer(x2,n_kernels=64,kernel_size=(5,5),border_mode='same')  #13

x4 = concatenate([x1, x3]) # 9,17
x4 = depthwise_conv_layer(x4, n_kernels=64,kernel_size=(5,5),border_mode='same')

x5 = MaxPooling2D(pool_size=(2, 2),)(x4)
x6 = depthwise_conv_layer(x5, n_kernels=128,kernel_size=(3,3),border_mode='same') 

x7_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x4)
x7_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x1)
x7 = concatenate([x6, x7_1, x7_2])
x7 = norm_conv_layer(x7, n_kernels=128,kernel_size=(5,5),border_mode='same')


x8_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x3)
x8_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x4)
x8 = concatenate([x6, x7,x8_1,x8_2])
x8 = depthwise_conv_layer(x8, n_kernels=128,kernel_size=(3,3),border_mode='same')


x9_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x1)
x9_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x3)
x9_3 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x4)
x9 = concatenate([x6,x7,x8,x9_1, x9_2,x9_3])
x9 = depthwise_conv_layer(x9, n_kernels=128,kernel_size=(5,5),border_mode='same')

x10_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x4)
x10 = concatenate([x6,x8,x9,x10_1])
x10 = MaxPooling2D(pool_size=(2, 2),)(x10)


#x11_1 = norm_conv_layer(x10, n_kernels=64,kernel_size=(5,5),border_mode='same')
x11_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x7)
x11 = concatenate([x10, x11_1])
x11 = norm_conv_layer(x11, n_kernels=256,kernel_size=(5,5),border_mode='same')


x12_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x8)
x12_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x2)
x12_3 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x4)
x12 = concatenate([x11, x12_1, x12_2,x12_3])
x12 = depthwise_conv_layer(x12, n_kernels=256,kernel_size=(5,5),border_mode='same')


x13_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x6)
x13_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x8)
x13_3 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x2)
x13 = concatenate([x11,x12,x13_1, x13_2,x13_3])
x13 = norm_conv_layer(x13, n_kernels=256,kernel_size=(3,3),border_mode='same')

x14_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x6)
x14_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x8)
x14_3 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x1)
x14_4 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x2)
x14_5 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x4)
x14 = concatenate([x12,x13,x14_1, x14_2,x14_3, x14_4, x14_5])
x14 = depthwise_conv_layer(x14, n_kernels=256,kernel_size=(5,5),border_mode='same')

x15_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x8)
x15_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x4)
x15 = concatenate([x12,x14,x15_1, x15_2])
x15 = norm_conv_layer(x15,n_kernels=32,kernel_size=(1,1),border_mode='same')  # 9

output = output_layer(x15, n_classes=10, kernel_size=(7,7)) # 24, 32

model = Model(inputs=inputs, outputs=output)
optimizer = SGD(lr=0.001)
model.compile(loss='categorical_crossentropy',
             optimizer=optimizer,
             metrics=['accuracy'])


model.summary()

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 50, 
                                 validation_data = (test_features, test_labels), verbose=1)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(64, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, depth_multiplier=1, padding="valid")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(64, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, depth_multiplier=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(128, kernel_size=(3, 3), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, depth_multiplier=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(128, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, depth_multiplier=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(256, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, depth_multiplier=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, kernel_size=(3, 3), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, kernel_size=(1, 1), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, kernel_size=(7, 7), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, padding="valid")`
#   import sys
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# separable_conv2d_8 (SeparableCo (None, 28, 28, 64)   331         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 28, 28, 64)   256         separable_conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 28, 28, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 28, 28, 64)   0           activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 28, 28, 64)   102464      dropout_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 28, 28, 64)   256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 28, 28, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 28, 28, 64)   0           activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 28, 28, 64)   102464      dropout_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 28, 28, 64)   256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 28, 28, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 28, 28, 64)   0           activation_16[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 28, 28, 128)  0           dropout_13[0][0]
#                                                                  dropout_15[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_9 (SeparableCo (None, 28, 28, 64)   11456       concatenate_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 28, 28, 64)   256         separable_conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 28, 28, 64)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 28, 28, 64)   0           activation_17[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 14, 14, 64)   0           dropout_16[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_10 (SeparableC (None, 14, 14, 128)  8896        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 14, 14, 128)  512         separable_conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 14, 14, 128)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 14, 14, 128)  0           activation_18[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 14, 14, 256)  0           dropout_16[0][0]
# __________________________________________________________________________________________________
# lambda_24 (Lambda)              (None, 14, 14, 256)  0           dropout_13[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 14, 14, 640)  0           dropout_17[0][0]
#                                                                  lambda_23[0][0]
#                                                                  lambda_24[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 14, 14, 128)  2048128     concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 14, 14, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 14, 14, 128)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 14, 14, 128)  0           activation_19[0][0]
# __________________________________________________________________________________________________
# lambda_25 (Lambda)              (None, 14, 14, 256)  0           dropout_15[0][0]
# __________________________________________________________________________________________________
# lambda_26 (Lambda)              (None, 14, 14, 256)  0           dropout_16[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 14, 14, 768)  0           dropout_17[0][0]
#                                                                  dropout_18[0][0]
#                                                                  lambda_25[0][0]
#                                                                  lambda_26[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_11 (SeparableC (None, 14, 14, 128)  105344      concatenate_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 14, 14, 128)  512         separable_conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 14, 14, 128)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 14, 14, 128)  0           activation_20[0][0]
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None, 14, 14, 256)  0           dropout_13[0][0]
# __________________________________________________________________________________________________
# lambda_28 (Lambda)              (None, 14, 14, 256)  0           dropout_15[0][0]
# __________________________________________________________________________________________________
# lambda_29 (Lambda)              (None, 14, 14, 256)  0           dropout_16[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 14, 14, 1152) 0           dropout_17[0][0]
#                                                                  dropout_18[0][0]
#                                                                  dropout_19[0][0]
#                                                                  lambda_27[0][0]
#                                                                  lambda_28[0][0]
#                                                                  lambda_29[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_12 (SeparableC (None, 14, 14, 128)  176384      concatenate_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 14, 14, 128)  512         separable_conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 14, 14, 128)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 14, 14, 128)  0           activation_21[0][0]
# __________________________________________________________________________________________________
# lambda_30 (Lambda)              (None, 14, 14, 256)  0           dropout_16[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 14, 14, 640)  0           dropout_17[0][0]
#                                                                  dropout_19[0][0]
#                                                                  dropout_20[0][0]
#                                                                  lambda_30[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 7, 7, 640)    0           concatenate_15[0][0]
# __________________________________________________________________________________________________
# lambda_31 (Lambda)              (None, 7, 7, 512)    0           dropout_18[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 7, 7, 1152)   0           max_pooling2d_4[0][0]
#                                                                  lambda_31[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 7, 7, 256)    7373056     concatenate_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 7, 7, 256)    1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 7, 7, 256)    0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 7, 7, 256)    0           activation_22[0][0]
# __________________________________________________________________________________________________
# lambda_32 (Lambda)              (None, 7, 7, 512)    0           dropout_19[0][0]
# __________________________________________________________________________________________________
# lambda_33 (Lambda)              (None, 7, 7, 1024)   0           dropout_14[0][0]
# __________________________________________________________________________________________________
# lambda_34 (Lambda)              (None, 7, 7, 1024)   0           dropout_16[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 7, 7, 2816)   0           dropout_21[0][0]
#                                                                  lambda_32[0][0]
#                                                                  lambda_33[0][0]
#                                                                  lambda_34[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_13 (SeparableC (None, 7, 7, 256)    791552      concatenate_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 7, 7, 256)    1024        separable_conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 7, 7, 256)    0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 7, 7, 256)    0           activation_23[0][0]
# __________________________________________________________________________________________________
# lambda_35 (Lambda)              (None, 7, 7, 512)    0           dropout_17[0][0]
# __________________________________________________________________________________________________
# lambda_36 (Lambda)              (None, 7, 7, 512)    0           dropout_19[0][0]
# __________________________________________________________________________________________________
# lambda_37 (Lambda)              (None, 7, 7, 1024)   0           dropout_14[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 7, 7, 2560)   0           dropout_21[0][0]
#                                                                  dropout_22[0][0]
#                                                                  lambda_35[0][0]
#                                                                  lambda_36[0][0]
#                                                                  lambda_37[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 7, 7, 256)    5898496     concatenate_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 7, 7, 256)    1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 7, 7, 256)    0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 7, 7, 256)    0           activation_24[0][0]
# __________________________________________________________________________________________________
# lambda_38 (Lambda)              (None, 7, 7, 512)    0           dropout_17[0][0]
# __________________________________________________________________________________________________
# lambda_39 (Lambda)              (None, 7, 7, 512)    0           dropout_19[0][0]
# __________________________________________________________________________________________________
# lambda_40 (Lambda)              (None, 7, 7, 1024)   0           dropout_13[0][0]
# __________________________________________________________________________________________________
# lambda_41 (Lambda)              (None, 7, 7, 1024)   0           dropout_14[0][0]
# __________________________________________________________________________________________________
# lambda_42 (Lambda)              (None, 7, 7, 1024)   0           dropout_16[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 7, 7, 4608)   0           dropout_22[0][0]
#                                                                  dropout_23[0][0]
#                                                                  lambda_38[0][0]
#                                                                  lambda_39[0][0]
#                                                                  lambda_40[0][0]
#                                                                  lambda_41[0][0]
#                                                                  lambda_42[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_14 (SeparableC (None, 7, 7, 256)    1295104     concatenate_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 7, 7, 256)    1024        separable_conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 7, 7, 256)    0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 7, 7, 256)    0           activation_25[0][0]
# __________________________________________________________________________________________________
# lambda_43 (Lambda)              (None, 7, 7, 512)    0           dropout_19[0][0]
# __________________________________________________________________________________________________
# lambda_44 (Lambda)              (None, 7, 7, 1024)   0           dropout_16[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 7, 7, 2048)   0           dropout_22[0][0]
#                                                                  dropout_24[0][0]
#                                                                  lambda_43[0][0]
#                                                                  lambda_44[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 7, 7, 32)     65568       concatenate_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 7, 7, 32)     128         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 7, 7, 32)     0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# dropout_25 (Dropout)            (None, 7, 7, 32)     0           activation_26[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 1, 1, 10)     15690       dropout_25[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 10)           0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 10)           0           flatten_2[0][0]
# ==================================================================================================
# Total params: 18,002,229
# Trainable params: 17,998,581
# Non-trainable params: 3,648
# __________________________________________________________________________________________________
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:90: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:90: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, steps_per_epoch=390, epochs=50)`
# Epoch 1/50
# 390/390 [==============================] - 225s 578ms/step - loss: 2.2609 - acc: 0.2344 - val_loss: 1.9557 - val_acc: 0.3271
# Epoch 2/50
# 390/390 [==============================] - 221s 566ms/step - loss: 1.9359 - acc: 0.3454 - val_loss: 1.8203 - val_acc: 0.3816
# Epoch 3/50
# 390/390 [==============================] - 221s 567ms/step - loss: 1.7962 - acc: 0.3950 - val_loss: 1.7170 - val_acc: 0.4172
# Epoch 4/50
# 390/390 [==============================] - 221s 567ms/step - loss: 1.7082 - acc: 0.4242 - val_loss: 1.6468 - val_acc: 0.4451
# Epoch 5/50
# 390/390 [==============================] - 221s 566ms/step - loss: 1.6446 - acc: 0.4486 - val_loss: 1.6101 - val_acc: 0.4596
# Epoch 6/50
# 390/390 [==============================] - 222s 568ms/step - loss: 1.5939 - acc: 0.4687 - val_loss: 1.6198 - val_acc: 0.4668
# Epoch 7/50
# 390/390 [==============================] - 221s 566ms/step - loss: 1.5543 - acc: 0.4851 - val_loss: 1.5331 - val_acc: 0.4895
# Epoch 8/50
# 390/390 [==============================] - 220s 565ms/step - loss: 1.5180 - acc: 0.4994 - val_loss: 1.5546 - val_acc: 0.4857
# Epoch 9/50
# 390/390 [==============================] - 221s 567ms/step - loss: 1.4880 - acc: 0.5111 - val_loss: 1.5239 - val_acc: 0.4998
# Epoch 10/50
# 390/390 [==============================] - 221s 567ms/step - loss: 1.4584 - acc: 0.5208 - val_loss: 1.4870 - val_acc: 0.5124
# Epoch 11/50
# 390/390 [==============================] - 222s 568ms/step - loss: 1.4330 - acc: 0.5290 - val_loss: 1.4669 - val_acc: 0.5233
# Epoch 12/50
# 390/390 [==============================] - 221s 566ms/step - loss: 1.4039 - acc: 0.5419 - val_loss: 1.3952 - val_acc: 0.5470
# Epoch 13/50
# 390/390 [==============================] - 221s 567ms/step - loss: 1.3806 - acc: 0.5531 - val_loss: 1.4059 - val_acc: 0.5450
# Epoch 14/50
# 390/390 [==============================] - 222s 568ms/step - loss: 1.3570 - acc: 0.5602 - val_loss: 1.4196 - val_acc: 0.5410
# Epoch 15/50
# 390/390 [==============================] - 221s 568ms/step - loss: 1.3362 - acc: 0.5690 - val_loss: 1.3551 - val_acc: 0.5660
# Epoch 16/50
# 390/390 [==============================] - 222s 570ms/step - loss: 1.3091 - acc: 0.5811 - val_loss: 1.3223 - val_acc: 0.5745
# Epoch 17/50
# 390/390 [==============================] - 221s 567ms/step - loss: 1.2914 - acc: 0.5847 - val_loss: 1.3449 - val_acc: 0.5728
# Epoch 18/50
# 390/390 [==============================] - 223s 572ms/step - loss: 1.2671 - acc: 0.5952 - val_loss: 1.2811 - val_acc: 0.5936
# Epoch 19/50
# 390/390 [==============================] - 221s 567ms/step - loss: 1.2501 - acc: 0.6010 - val_loss: 1.2845 - val_acc: 0.5931
# 390/390 [==============================] - 225s 578ms/step - loss: 0.9042 - acc: 0.7321 - val_loss: 1.0620 - val_acc: 0.6801
# Epoch 41/50
# 390/390 [==============================] - 225s 577ms/step - loss: 0.8918 - acc: 0.7323 - val_loss: 1.0314 - val_acc: 0.6863
# Epoch 42/50
# 390/390 [==============================] - 225s 577ms/step - loss: 0.8810 - acc: 0.7372 - val_loss: 1.0292 - val_acc: 0.6871
# Epoch 43/50
# 390/390 [==============================] - 224s 575ms/step - loss: 0.8656 - acc: 0.7421 - val_loss: 1.0096 - val_acc: 0.6964
# Epoch 44/50
# 390/390 [==============================] - 224s 574ms/step - loss: 0.8529 - acc: 0.7479 - val_loss: 1.0495 - val_acc: 0.6826
# Epoch 45/50
# 390/390 [==============================] - 224s 574ms/step - loss: 0.8443 - acc: 0.7530 - val_loss: 1.0086 - val_acc: 0.6942
# Epoch 46/50
# 390/390 [==============================] - 221s 568ms/step - loss: 0.8347 - acc: 0.7537 - val_loss: 0.9715 - val_acc: 0.7110
# Epoch 47/50
# 390/390 [==============================] - 222s 568ms/step - loss: 0.8212 - acc: 0.7581 - val_loss: 0.9487 - val_acc: 0.7151
# Epoch 48/50
# 390/390 [==============================] - 221s 567ms/step - loss: 0.8121 - acc: 0.7648 - val_loss: 0.9948 - val_acc: 0.7012
# Epoch 49/50
# 390/390 [==============================] - 221s 566ms/step - loss: 0.8025 - acc: 0.7659 - val_loss: 0.9642 - val_acc: 0.7108
# Epoch 50/50
# 390/390 [==============================] - 221s 566ms/step - loss: 0.7956 - acc: 0.7668 - val_loss: 0.9421 - val_acc: 0.7176
# Model took 11136.43 seconds to train
# Accuracy on test data is: 71.76

# %%
inputs = Input(shape=(32,32,3))

x1 = depthwise_conv_layer(inputs, n_kernels=64,kernel_size=(5,5),border_mode='valid')

x2 = norm_conv_layer(x1,n_kernels=64,kernel_size=(5,5),border_mode='same')  # 9

x3 = norm_conv_layer(x2,n_kernels=64,kernel_size=(5,5),border_mode='same')  #13

x4 = concatenate([x1, x3]) # 9,17
x4 = depthwise_conv_layer(x4, n_kernels=64,kernel_size=(5,5),border_mode='same')

x5 = MaxPooling2D(pool_size=(2, 2),)(x4)
x5 = norm_conv_layer(x5,n_kernels=32,kernel_size=(1,1),border_mode='same')

x6 = depthwise_conv_layer(x5, n_kernels=128,kernel_size=(3,3),border_mode='same') 

x7_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x4)
x7_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x1)
x7 = concatenate([x6, x7_1, x7_2])
x7 = norm_conv_layer(x7, n_kernels=128,kernel_size=(5,5),border_mode='same')


x8_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x3)
x8_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x4)
x8 = concatenate([x6, x7,x8_1,x8_2])
x8 = depthwise_conv_layer(x8, n_kernels=128,kernel_size=(3,3),border_mode='same')


x9_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x1)
x9_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x3)
x9_3 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x4)
x9 = concatenate([x6,x7,x8,x9_1, x9_2,x9_3])
x9 = depthwise_conv_layer(x9, n_kernels=128,kernel_size=(5,5),border_mode='same')

x10_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x4)
x10 = concatenate([x6,x8,x9,x10_1])
x10 = MaxPooling2D(pool_size=(2, 2),)(x10)
x10 = norm_conv_layer(x10,n_kernels=32,kernel_size=(1,1),border_mode='same')

#x11_1 = norm_conv_layer(x10, n_kernels=64,kernel_size=(5,5),border_mode='same')
x11_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x7)
x11 = concatenate([x10, x11_1])
x11 = norm_conv_layer(x11, n_kernels=256,kernel_size=(5,5),border_mode='same')


x12_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x8)
x12_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x2)
x12_3 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x4)
x12 = concatenate([x11, x12_1, x12_2,x12_3])
x12 = depthwise_conv_layer(x12, n_kernels=256,kernel_size=(5,5),border_mode='same')


x13_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x6)
x13_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x8)
x13_3 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x2)
x13 = concatenate([x11,x12,x13_1, x13_2,x13_3])
x13 = norm_conv_layer(x13, n_kernels=256,kernel_size=(3,3),border_mode='same')

x14_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x6)
x14_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x8)
x14_3 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x1)
x14_4 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x2)
x14_5 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x4)
x14 = concatenate([x12,x13,x14_1, x14_2,x14_3, x14_4, x14_5])
x14 = depthwise_conv_layer(x14, n_kernels=256,kernel_size=(5,5),border_mode='same')

x15_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x8)
x15_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x4)
x15 = concatenate([x12,x14,x15_1, x15_2])
x15 = norm_conv_layer(x15,n_kernels=32,kernel_size=(1,1),border_mode='same')  # 9

output = output_layer(x15, n_classes=10, kernel_size=(7,7)) # 24, 32

model = Model(inputs=inputs, outputs=output)
optimizer = SGD(lr=0.001)
model.compile(loss='categorical_crossentropy',
             optimizer=optimizer,
             metrics=['accuracy'])


model.summary()

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = (test_features, test_labels), verbose=1)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0904 02:50:49.489091 139890681915264 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0904 02:50:49.539169 139890681915264 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(64, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, depth_multiplier=1, padding="valid")`
#
# W0904 02:50:49.554982 139890681915264 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0904 02:50:49.616634 139890681915264 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0904 02:50:49.617752 139890681915264 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0904 02:50:53.770566 139890681915264 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0904 02:50:53.965934 139890681915264 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(64, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, depth_multiplier=1, padding="same")`
#
# W0904 02:50:54.339225 139890681915264 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, kernel_size=(1, 1), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(128, kernel_size=(3, 3), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, depth_multiplier=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(128, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, depth_multiplier=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(256, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, depth_multiplier=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, kernel_size=(3, 3), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, kernel_size=(7, 7), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, padding="valid")`
#   import sys
# W0904 02:50:55.941051 139890681915264 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:92: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:92: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, steps_per_epoch=390, epochs=100)`
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# separable_conv2d_1 (SeparableCo (None, 28, 28, 64)   331         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 28, 28, 64)   256         separable_conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 28, 28, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 28, 28, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 28, 28, 64)   102464      dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 28, 28, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 28, 28, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 28, 28, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 28, 28, 64)   102464      dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 28, 28, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 28, 28, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 28, 28, 64)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 28, 28, 128)  0           dropout_1[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_2 (SeparableCo (None, 28, 28, 64)   11456       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 28, 28, 64)   256         separable_conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 28, 28, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 28, 28, 64)   0           activation_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 14, 14, 64)   0           dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 14, 14, 32)   2080        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 14, 14, 32)   128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 14, 14, 32)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 14, 14, 32)   0           activation_5[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_3 (SeparableCo (None, 14, 14, 128)  4512        dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 14, 14, 128)  512         separable_conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 14, 14, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 14, 14, 128)  0           activation_6[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 14, 14, 256)  0           dropout_4[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 14, 14, 256)  0           dropout_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 14, 14, 640)  0           dropout_6[0][0]
#                                                                  lambda_1[0][0]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 14, 14, 128)  2048128     concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 14, 14, 128)  512         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 14, 14, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 14, 14, 128)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 14, 14, 256)  0           dropout_3[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 14, 14, 256)  0           dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 14, 14, 768)  0           dropout_6[0][0]
#                                                                  dropout_7[0][0]
#                                                                  lambda_3[0][0]
#                                                                  lambda_4[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_4 (SeparableCo (None, 14, 14, 128)  105344      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 14, 14, 128)  512         separable_conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 14, 14, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 14, 14, 128)  0           activation_8[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 14, 14, 256)  0           dropout_1[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 14, 14, 256)  0           dropout_3[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 14, 14, 256)  0           dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 14, 14, 1152) 0           dropout_6[0][0]
#                                                                  dropout_7[0][0]
#                                                                  dropout_8[0][0]
#                                                                  lambda_5[0][0]
#                                                                  lambda_6[0][0]
#                                                                  lambda_7[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_5 (SeparableCo (None, 14, 14, 128)  176384      concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 14, 14, 128)  512         separable_conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 14, 14, 128)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 14, 14, 128)  0           activation_9[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 14, 14, 256)  0           dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 14, 14, 640)  0           dropout_6[0][0]
#                                                                  dropout_8[0][0]
#                                                                  dropout_9[0][0]
#                                                                  lambda_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 7, 7, 640)    0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 7, 7, 32)     20512       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 7, 7, 32)     128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 7, 7, 32)     0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 7, 7, 32)     0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 7, 7, 512)    0           dropout_7[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 7, 7, 544)    0           dropout_10[0][0]
#                                                                  lambda_9[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 7, 7, 256)    3481856     concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 7, 7, 256)    1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 7, 7, 256)    0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 7, 7, 256)    0           activation_11[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 7, 7, 512)    0           dropout_8[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 7, 7, 1024)   0           dropout_2[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 7, 7, 1024)   0           dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 7, 7, 2816)   0           dropout_11[0][0]
#                                                                  lambda_10[0][0]
#                                                                  lambda_11[0][0]
#                                                                  lambda_12[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_6 (SeparableCo (None, 7, 7, 256)    791552      concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 7, 7, 256)    1024        separable_conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 7, 7, 256)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 7, 7, 256)    0           activation_12[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 7, 7, 512)    0           dropout_6[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 7, 7, 512)    0           dropout_8[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 7, 7, 1024)   0           dropout_2[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 7, 7, 2560)   0           dropout_11[0][0]
#                                                                  dropout_12[0][0]
#                                                                  lambda_13[0][0]
#                                                                  lambda_14[0][0]
#                                                                  lambda_15[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 7, 7, 256)    5898496     concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 7, 7, 256)    1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 7, 7, 256)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 7, 7, 256)    0           activation_13[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 7, 7, 512)    0           dropout_6[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 7, 7, 512)    0           dropout_8[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 7, 7, 1024)   0           dropout_1[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 7, 7, 1024)   0           dropout_2[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 7, 7, 1024)   0           dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 7, 7, 4608)   0           dropout_12[0][0]
#                                                                  dropout_13[0][0]
#                                                                  lambda_16[0][0]
#                                                                  lambda_17[0][0]
#                                                                  lambda_18[0][0]
#                                                                  lambda_19[0][0]
#                                                                  lambda_20[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_7 (SeparableCo (None, 7, 7, 256)    1295104     concatenate_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 7, 7, 256)    1024        separable_conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 7, 7, 256)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 7, 7, 256)    0           activation_14[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 7, 7, 512)    0           dropout_8[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 7, 7, 1024)   0           dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 7, 7, 2048)   0           dropout_12[0][0]
#                                                                  dropout_14[0][0]
#                                                                  lambda_21[0][0]
#                                                                  lambda_22[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 7, 7, 32)     65568       concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 7, 7, 32)     128         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 7, 7, 32)     0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 7, 7, 32)     0           activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 1, 1, 10)     15690       dropout_15[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 10)           0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 10)           0           flatten_1[0][0]
# ==================================================================================================
# Total params: 14,129,493
# Trainable params: 14,125,717
# Non-trainable params: 3,776
# __________________________________________________________________________________________________
# W0904 02:50:56.227114 139890681915264 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/100
# 390/390 [==============================] - 234s 599ms/step - loss: 2.2367 - acc: 0.2410 - val_loss: 1.9229 - val_acc: 0.3494
# Epoch 2/100
# 390/390 [==============================] - 219s 561ms/step - loss: 1.9276 - acc: 0.3471 - val_loss: 1.8035 - val_acc: 0.3955
# Epoch 3/100
# 390/390 [==============================] - 219s 561ms/step - loss: 1.8107 - acc: 0.3912 - val_loss: 1.7372 - val_acc: 0.4225
# Epoch 4/100
# 390/390 [==============================] - 219s 561ms/step - loss: 1.7319 - acc: 0.4191 - val_loss: 1.6540 - val_acc: 0.4508
# Epoch 5/100
# 390/390 [==============================] - 219s 562ms/step - loss: 1.6710 - acc: 0.4417 - val_loss: 1.6142 - val_acc: 0.4662
# Epoch 6/100
# 390/390 [==============================] - 220s 564ms/step - loss: 1.6165 - acc: 0.4634 - val_loss: 1.5723 - val_acc: 0.4805
# Epoch 7/100
# 390/390 [==============================] - 219s 562ms/step - loss: 1.5678 - acc: 0.4810 - val_loss: 1.5580 - val_acc: 0.4907
# Epoch 49/100
# 390/390 [==============================] - 218s 560ms/step - loss: 0.8195 - acc: 0.7634 - val_loss: 0.9393 - val_acc: 0.7226
# Epoch 50/100
# 390/390 [==============================] - 218s 559ms/step - loss: 0.8095 - acc: 0.7656 - val_loss: 1.0498 - val_acc: 0.6848
# Epoch 51/100
# 390/390 [==============================] - 218s 559ms/step - loss: 0.8034 - acc: 0.7671 - val_loss: 0.9386 - val_acc: 0.7177
# Epoch 52/100
# 390/390 [==============================] - 218s 558ms/step - loss: 0.7935 - acc: 0.7716 - val_loss: 0.9676 - val_acc: 0.7137
# Epoch 53/100
# 390/390 [==============================] - 218s 559ms/step - loss: 0.7843 - acc: 0.7732 - val_loss: 0.9299 - val_acc: 0.7200
# Epoch 54/100
# 390/390 [==============================] - 218s 559ms/step - loss: 0.7805 - acc: 0.7742 - val_loss: 0.9051 - val_acc: 0.7334
# Epoch 55/100
# 390/390 [==============================] - 218s 559ms/step - loss: 0.7672 - acc: 0.7799 - val_loss: 0.9442 - val_acc: 0.7218
# Epoch 56/100
# 390/390 [==============================] - 218s 559ms/step - loss: 0.7645 - acc: 0.7810 - val_loss: 0.9349 - val_acc: 0.7258
# Epoch 57/100
# 390/390 [==============================] - 218s 558ms/step - loss: 0.7569 - acc: 0.7842 - val_loss: 0.9887 - val_acc: 0.7069
# Epoch 58/100
# 390/390 [==============================] - 218s 559ms/step - loss: 0.7484 - acc: 0.7862 - val_loss: 0.9083 - val_acc: 0.7355
# Epoch 59/100
# 390/390 [==============================] - 218s 559ms/step - loss: 0.7382 - acc: 0.7902 - val_loss: 0.8845 - val_acc: 0.7385
# Epoch 60/100
# 390/390 [==============================] - 218s 558ms/step - loss: 0.7288 - acc: 0.7927 - val_loss: 0.9477 - val_acc: 0.7238
# Epoch 61/100
# 390/390 [==============================] - 218s 559ms/step - loss: 0.7191 - acc: 0.7973 - val_loss: 0.8863 - val_acc: 0.7446
# Epoch 62/100
#  73/390 [====>.........................] - ETA: 2:47 - loss: 0.7205 - acc: 0.7936

# %%
inputs = Input(shape=(32,32,3))

x1 = depthwise_conv_layer(inputs, n_kernels=64,kernel_size=(5,5),border_mode='valid')

x2 = norm_conv_layer(x1,n_kernels=64,kernel_size=(5,5),border_mode='same')  # 9

x3 = norm_conv_layer(x2,n_kernels=64,kernel_size=(5,5),border_mode='same')  #13

x4 = concatenate([x1, x3]) # 9,17
x4 = depthwise_conv_layer(x4, n_kernels=64,kernel_size=(5,5),border_mode='same')

x5 = MaxPooling2D(pool_size=(2, 2),)(x4)
x5 = norm_conv_layer(x5,n_kernels=32,kernel_size=(1,1),border_mode='same')

x6 = depthwise_conv_layer(x5, n_kernels=128,kernel_size=(3,3),border_mode='same') 

x7_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x4)
x7_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x1)
x7 = concatenate([x6, x7_1, x7_2])
x7 = norm_conv_layer(x7, n_kernels=128,kernel_size=(5,5),border_mode='same')


x8_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x3)
x8_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x4)
x8 = concatenate([x6, x7,x8_1,x8_2])
x8 = depthwise_conv_layer(x8, n_kernels=128,kernel_size=(3,3),border_mode='same')


x9_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x1)
x9_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x3)
x9_3 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x4)
x9 = concatenate([x6,x7,x8,x9_1, x9_2,x9_3])
x9 = depthwise_conv_layer(x9, n_kernels=128,kernel_size=(5,5),border_mode='same')

x10_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x4)
x10 = concatenate([x6,x8,x9,x10_1])
x10 = MaxPooling2D(pool_size=(2, 2),)(x10)
x10 = norm_conv_layer(x10,n_kernels=32,kernel_size=(1,1),border_mode='same')

#x11_1 = norm_conv_layer(x10, n_kernels=64,kernel_size=(5,5),border_mode='same')
x11_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x7)
x11 = concatenate([x10, x11_1])
x11 = norm_conv_layer(x11, n_kernels=256,kernel_size=(5,5),border_mode='same')


x12_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x8)
x12_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x2)
x12_3 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x4)
x12 = concatenate([x11, x12_1, x12_2,x12_3])
x12 = depthwise_conv_layer(x12, n_kernels=256,kernel_size=(5,5),border_mode='same')


x13_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x6)
x13_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x8)
x13_3 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x2)
x13 = concatenate([x11,x12,x13_1, x13_2,x13_3])
x13 = norm_conv_layer(x13, n_kernels=256,kernel_size=(3,3),border_mode='same')

x14_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x6)
x14_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x8)
x14_3 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x1)
x14_4 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x2)
x14_5 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x4)
x14 = concatenate([x12,x13,x14_1, x14_2,x14_3, x14_4, x14_5])
x14 = depthwise_conv_layer(x14, n_kernels=256,kernel_size=(5,5),border_mode='same')

x15_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x8)
x15_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x4)
x15 = concatenate([x12,x14,x15_1, x15_2])
x15 = norm_conv_layer(x15,n_kernels=32,kernel_size=(1,1),border_mode='same')  # 9

output = output_layer(x15, n_classes=10, kernel_size=(7,7)) # 24, 32

model = Model(inputs=inputs, outputs=output)
optimizer = SGD(lr=0.01)
model.compile(loss='categorical_crossentropy',
             optimizer=optimizer,
             metrics=['accuracy'])


model.summary()

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 30, 
                                 validation_data = (test_features, test_labels), verbose=1)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0904 12:34:07.856184 140314241509248 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0904 12:34:07.898907 140314241509248 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(64, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, depth_multiplier=1, padding="valid")`
#
# W0904 12:34:07.911858 140314241509248 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0904 12:34:07.971427 140314241509248 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0904 12:34:07.972591 140314241509248 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0904 12:34:12.232491 140314241509248 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0904 12:34:12.411367 140314241509248 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(64, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, depth_multiplier=1, padding="same")`
#
# W0904 12:34:12.820835 140314241509248 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, kernel_size=(1, 1), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(128, kernel_size=(3, 3), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, depth_multiplier=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(128, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, depth_multiplier=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(256, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, depth_multiplier=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, kernel_size=(3, 3), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, kernel_size=(7, 7), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, padding="valid")`
#   import sys
# W0904 12:34:14.381945 140314241509248 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:92: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:92: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, steps_per_epoch=390, epochs=30)`
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# separable_conv2d_1 (SeparableCo (None, 28, 28, 64)   331         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 28, 28, 64)   256         separable_conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 28, 28, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 28, 28, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 28, 28, 64)   102464      dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 28, 28, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 28, 28, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 28, 28, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 28, 28, 64)   102464      dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 28, 28, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 28, 28, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 28, 28, 64)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 28, 28, 128)  0           dropout_1[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_2 (SeparableCo (None, 28, 28, 64)   11456       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 28, 28, 64)   256         separable_conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 28, 28, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 28, 28, 64)   0           activation_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 14, 14, 64)   0           dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 14, 14, 32)   2080        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 14, 14, 32)   128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 14, 14, 32)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 14, 14, 32)   0           activation_5[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_3 (SeparableCo (None, 14, 14, 128)  4512        dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 14, 14, 128)  512         separable_conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 14, 14, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 14, 14, 128)  0           activation_6[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 14, 14, 256)  0           dropout_4[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 14, 14, 256)  0           dropout_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 14, 14, 640)  0           dropout_6[0][0]
#                                                                  lambda_1[0][0]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 14, 14, 128)  2048128     concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 14, 14, 128)  512         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 14, 14, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 14, 14, 128)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 14, 14, 256)  0           dropout_3[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 14, 14, 256)  0           dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 14, 14, 768)  0           dropout_6[0][0]
#                                                                  dropout_7[0][0]
#                                                                  lambda_3[0][0]
#                                                                  lambda_4[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_4 (SeparableCo (None, 14, 14, 128)  105344      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 14, 14, 128)  512         separable_conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 14, 14, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 14, 14, 128)  0           activation_8[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 14, 14, 256)  0           dropout_1[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 14, 14, 256)  0           dropout_3[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 14, 14, 256)  0           dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 14, 14, 1152) 0           dropout_6[0][0]
#                                                                  dropout_7[0][0]
#                                                                  dropout_8[0][0]
#                                                                  lambda_5[0][0]
#                                                                  lambda_6[0][0]
#                                                                  lambda_7[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_5 (SeparableCo (None, 14, 14, 128)  176384      concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 14, 14, 128)  512         separable_conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 14, 14, 128)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 14, 14, 128)  0           activation_9[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 14, 14, 256)  0           dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 14, 14, 640)  0           dropout_6[0][0]
#                                                                  dropout_8[0][0]
#                                                                  dropout_9[0][0]
#                                                                  lambda_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 7, 7, 640)    0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 7, 7, 32)     20512       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 7, 7, 32)     128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 7, 7, 32)     0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 7, 7, 32)     0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 7, 7, 512)    0           dropout_7[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 7, 7, 544)    0           dropout_10[0][0]
#                                                                  lambda_9[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 7, 7, 256)    3481856     concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 7, 7, 256)    1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 7, 7, 256)    0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 7, 7, 256)    0           activation_11[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 7, 7, 512)    0           dropout_8[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 7, 7, 1024)   0           dropout_2[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 7, 7, 1024)   0           dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 7, 7, 2816)   0           dropout_11[0][0]
#                                                                  lambda_10[0][0]
#                                                                  lambda_11[0][0]
#                                                                  lambda_12[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_6 (SeparableCo (None, 7, 7, 256)    791552      concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 7, 7, 256)    1024        separable_conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 7, 7, 256)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 7, 7, 256)    0           activation_12[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 7, 7, 512)    0           dropout_6[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 7, 7, 512)    0           dropout_8[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 7, 7, 1024)   0           dropout_2[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 7, 7, 2560)   0           dropout_11[0][0]
#                                                                  dropout_12[0][0]
#                                                                  lambda_13[0][0]
#                                                                  lambda_14[0][0]
#                                                                  lambda_15[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 7, 7, 256)    5898496     concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 7, 7, 256)    1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 7, 7, 256)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 7, 7, 256)    0           activation_13[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 7, 7, 512)    0           dropout_6[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 7, 7, 512)    0           dropout_8[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 7, 7, 1024)   0           dropout_1[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 7, 7, 1024)   0           dropout_2[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 7, 7, 1024)   0           dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 7, 7, 4608)   0           dropout_12[0][0]
#                                                                  dropout_13[0][0]
#                                                                  lambda_16[0][0]
#                                                                  lambda_17[0][0]
#                                                                  lambda_18[0][0]
#                                                                  lambda_19[0][0]
#                                                                  lambda_20[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_7 (SeparableCo (None, 7, 7, 256)    1295104     concatenate_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 7, 7, 256)    1024        separable_conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 7, 7, 256)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 7, 7, 256)    0           activation_14[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 7, 7, 512)    0           dropout_8[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 7, 7, 1024)   0           dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 7, 7, 2048)   0           dropout_12[0][0]
#                                                                  dropout_14[0][0]
#                                                                  lambda_21[0][0]
#                                                                  lambda_22[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 7, 7, 32)     65568       concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 7, 7, 32)     128         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 7, 7, 32)     0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 7, 7, 32)     0           activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 1, 1, 10)     15690       dropout_15[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 10)           0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 10)           0           flatten_1[0][0]
# ==================================================================================================
# Total params: 14,129,493
# Trainable params: 14,125,717
# Non-trainable params: 3,776
# __________________________________________________________________________________________________
# W0904 12:34:14.670409 140314241509248 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/30
# 390/390 [==============================] - 235s 602ms/step - loss: 1.7822 - acc: 0.4025 - val_loss: 1.5347 - val_acc: 0.4939
# Epoch 2/30
# 390/390 [==============================] - 221s 566ms/step - loss: 1.4367 - acc: 0.5311 - val_loss: 1.3471 - val_acc: 0.5621
# Epoch 3/30
# 390/390 [==============================] - 221s 566ms/step - loss: 1.2658 - acc: 0.5968 - val_loss: 1.2113 - val_acc: 0.6176
# Epoch 4/30
# 390/390 [==============================] - 221s 567ms/step - loss: 1.1416 - acc: 0.6428 - val_loss: 1.1886 - val_acc: 0.6286
# Epoch 5/30
# Epoch 26/30
# 390/390 [==============================] - 221s 566ms/step - loss: 0.3221 - acc: 0.9366 - val_loss: 0.8345 - val_acc: 0.7896
# Epoch 27/30
# 390/390 [==============================] - 221s 567ms/step - loss: 0.3033 - acc: 0.9433 - val_loss: 0.8451 - val_acc: 0.7900
# Epoch 28/30
# 390/390 [==============================] - 220s 565ms/step - loss: 0.2940 - acc: 0.9464 - val_loss: 1.0917 - val_acc: 0.7536
# Epoch 29/30
# 390/390 [==============================] - 220s 564ms/step - loss: 0.2826 - acc: 0.9500 - val_loss: 0.9841 - val_acc: 0.7631
# Epoch 30/30
# 390/390 [==============================] - 220s 564ms/step - loss: 0.2682 - acc: 0.9560 - val_loss: 0.8599 - val_acc: 0.7885
# Model took 6632.77 seconds to train
# Accuracy on test data is: 78.84

# %%
inputs = Input(shape=(32,32,3))

x1 = depthwise_conv_layer(inputs, n_kernels=64,kernel_size=(5,5),border_mode='valid')

x2 = norm_conv_layer(x1,n_kernels=64,kernel_size=(5,5),border_mode='same')  # 9

x3 = norm_conv_layer(x2,n_kernels=64,kernel_size=(5,5),border_mode='same')  #13

x4 = concatenate([x1, x3]) # 9,17
x4 = depthwise_conv_layer(x4, n_kernels=64,kernel_size=(5,5),border_mode='same')

x5 = MaxPooling2D(pool_size=(2, 2),)(x4)
x5 = norm_conv_layer(x5,n_kernels=32,kernel_size=(1,1),border_mode='same')

x6 = depthwise_conv_layer(x5, n_kernels=128,kernel_size=(3,3),border_mode='same') 

x7_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x4)
x7_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x1)
x7 = concatenate([x6, x7_1, x7_2])
x7 = norm_conv_layer(x7, n_kernels=128,kernel_size=(5,5),border_mode='same')


x8_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x3)
x8_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x4)
x8 = concatenate([x6, x7,x8_1,x8_2])
x8 = depthwise_conv_layer(x8, n_kernels=128,kernel_size=(3,3),border_mode='same')


x9_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x1)
x9_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x3)
x9_3 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x4)
x9 = concatenate([x6,x7,x8,x9_1, x9_2,x9_3])
x9 = depthwise_conv_layer(x9, n_kernels=128,kernel_size=(5,5),border_mode='same')

x10_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x4)
x10 = concatenate([x6,x8,x9,x10_1])
x10 = MaxPooling2D(pool_size=(2, 2),)(x10)
x10 = norm_conv_layer(x10,n_kernels=32,kernel_size=(1,1),border_mode='same')

#x11_1 = norm_conv_layer(x10, n_kernels=64,kernel_size=(5,5),border_mode='same')
x11_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x7)
x11 = concatenate([x10, x11_1])
x11 = norm_conv_layer(x11, n_kernels=256,kernel_size=(5,5),border_mode='same')


x12_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x8)
x12_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x2)
x12_3 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x4)
x12 = concatenate([x11, x12_1, x12_2,x12_3])
x12 = depthwise_conv_layer(x12, n_kernels=256,kernel_size=(5,5),border_mode='same')


x13_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x6)
x13_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x8)
x13_3 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x2)
x13 = concatenate([x11,x12,x13_1, x13_2,x13_3])
x13 = norm_conv_layer(x13, n_kernels=256,kernel_size=(3,3),border_mode='same')

x14_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x6)
x14_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x8)
x14_3 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x1)
x14_4 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x2)
x14_5 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x4)
x14 = concatenate([x12,x13,x14_1, x14_2,x14_3, x14_4, x14_5])
x14 = depthwise_conv_layer(x14, n_kernels=256,kernel_size=(5,5),border_mode='same')

x15_1 = Lambda(lambda x:tf.space_to_depth(x, block_size=2))(x8)
x15_2 = Lambda(lambda x:tf.space_to_depth(x, block_size=4))(x4)
x15 = concatenate([x12,x14,x15_1, x15_2])
x15 = norm_conv_layer(x15,n_kernels=32,kernel_size=(1,1),border_mode='same')  # 9

output = output_layer(x15, n_classes=10, kernel_size=(7,7)) # 24, 32

model = Model(inputs=inputs, outputs=output)
optimizer = SGD(lr=0.005)
model.compile(loss='categorical_crossentropy',
             optimizer=optimizer,
             metrics=['accuracy'])


model.summary()

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 30, 
                                 validation_data = (test_features, test_labels), verbose=1)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0904 17:39:41.535131 140348486625152 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0904 17:39:41.574585 140348486625152 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(64, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, depth_multiplier=1, padding="valid")`
#
# W0904 17:39:41.585799 140348486625152 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0904 17:39:41.643601 140348486625152 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0904 17:39:41.646970 140348486625152 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0904 17:39:44.965524 140348486625152 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0904 17:39:45.143772 140348486625152 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(64, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, depth_multiplier=1, padding="same")`
#
# W0904 17:39:45.551780 140348486625152 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, kernel_size=(1, 1), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(128, kernel_size=(3, 3), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, depth_multiplier=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(128, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, depth_multiplier=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(256, kernel_size=(5, 5), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, depth_multiplier=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, kernel_size=(3, 3), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, kernel_size=(7, 7), strides=1, kernel_regularizer=<keras.reg..., dilation_rate=1, padding="valid")`
#   import sys
# W0904 17:39:47.122444 140348486625152 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:92: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:92: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, steps_per_epoch=390, epochs=30)`
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# separable_conv2d_1 (SeparableCo (None, 28, 28, 64)   331         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 28, 28, 64)   256         separable_conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 28, 28, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 28, 28, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 28, 28, 64)   102464      dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 28, 28, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 28, 28, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 28, 28, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 28, 28, 64)   102464      dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 28, 28, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 28, 28, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 28, 28, 64)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 28, 28, 128)  0           dropout_1[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_2 (SeparableCo (None, 28, 28, 64)   11456       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 28, 28, 64)   256         separable_conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 28, 28, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 28, 28, 64)   0           activation_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 14, 14, 64)   0           dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 14, 14, 32)   2080        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 14, 14, 32)   128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 14, 14, 32)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 14, 14, 32)   0           activation_5[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_3 (SeparableCo (None, 14, 14, 128)  4512        dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 14, 14, 128)  512         separable_conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 14, 14, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 14, 14, 128)  0           activation_6[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 14, 14, 256)  0           dropout_4[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 14, 14, 256)  0           dropout_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 14, 14, 640)  0           dropout_6[0][0]
#                                                                  lambda_1[0][0]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 14, 14, 128)  2048128     concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 14, 14, 128)  512         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 14, 14, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 14, 14, 128)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 14, 14, 256)  0           dropout_3[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 14, 14, 256)  0           dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 14, 14, 768)  0           dropout_6[0][0]
#                                                                  dropout_7[0][0]
#                                                                  lambda_3[0][0]
#                                                                  lambda_4[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_4 (SeparableCo (None, 14, 14, 128)  105344      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 14, 14, 128)  512         separable_conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 14, 14, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 14, 14, 128)  0           activation_8[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 14, 14, 256)  0           dropout_1[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 14, 14, 256)  0           dropout_3[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 14, 14, 256)  0           dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 14, 14, 1152) 0           dropout_6[0][0]
#                                                                  dropout_7[0][0]
#                                                                  dropout_8[0][0]
#                                                                  lambda_5[0][0]
#                                                                  lambda_6[0][0]
#                                                                  lambda_7[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_5 (SeparableCo (None, 14, 14, 128)  176384      concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 14, 14, 128)  512         separable_conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 14, 14, 128)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 14, 14, 128)  0           activation_9[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 14, 14, 256)  0           dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 14, 14, 640)  0           dropout_6[0][0]
#                                                                  dropout_8[0][0]
#                                                                  dropout_9[0][0]
#                                                                  lambda_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 7, 7, 640)    0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 7, 7, 32)     20512       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 7, 7, 32)     128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 7, 7, 32)     0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 7, 7, 32)     0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 7, 7, 512)    0           dropout_7[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 7, 7, 544)    0           dropout_10[0][0]
#                                                                  lambda_9[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 7, 7, 256)    3481856     concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 7, 7, 256)    1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 7, 7, 256)    0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 7, 7, 256)    0           activation_11[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 7, 7, 512)    0           dropout_8[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 7, 7, 1024)   0           dropout_2[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 7, 7, 1024)   0           dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 7, 7, 2816)   0           dropout_11[0][0]
#                                                                  lambda_10[0][0]
#                                                                  lambda_11[0][0]
#                                                                  lambda_12[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_6 (SeparableCo (None, 7, 7, 256)    791552      concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 7, 7, 256)    1024        separable_conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 7, 7, 256)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 7, 7, 256)    0           activation_12[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 7, 7, 512)    0           dropout_6[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 7, 7, 512)    0           dropout_8[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 7, 7, 1024)   0           dropout_2[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 7, 7, 2560)   0           dropout_11[0][0]
#                                                                  dropout_12[0][0]
#                                                                  lambda_13[0][0]
#                                                                  lambda_14[0][0]
#                                                                  lambda_15[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 7, 7, 256)    5898496     concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 7, 7, 256)    1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 7, 7, 256)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 7, 7, 256)    0           activation_13[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 7, 7, 512)    0           dropout_6[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 7, 7, 512)    0           dropout_8[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 7, 7, 1024)   0           dropout_1[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 7, 7, 1024)   0           dropout_2[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 7, 7, 1024)   0           dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 7, 7, 4608)   0           dropout_12[0][0]
#                                                                  dropout_13[0][0]
#                                                                  lambda_16[0][0]
#                                                                  lambda_17[0][0]
#                                                                  lambda_18[0][0]
#                                                                  lambda_19[0][0]
#                                                                  lambda_20[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_7 (SeparableCo (None, 7, 7, 256)    1295104     concatenate_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 7, 7, 256)    1024        separable_conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 7, 7, 256)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 7, 7, 256)    0           activation_14[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 7, 7, 512)    0           dropout_8[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 7, 7, 1024)   0           dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 7, 7, 2048)   0           dropout_12[0][0]
#                                                                  dropout_14[0][0]
#                                                                  lambda_21[0][0]
#                                                                  lambda_22[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 7, 7, 32)     65568       concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 7, 7, 32)     128         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 7, 7, 32)     0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 7, 7, 32)     0           activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 1, 1, 10)     15690       dropout_15[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 10)           0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 10)           0           flatten_1[0][0]
# ==================================================================================================
# Total params: 14,129,493
# Trainable params: 14,125,717
# Non-trainable params: 3,776
# __________________________________________________________________________________________________
# W0904 17:39:47.417324 140348486625152 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/30
# 390/390 [==============================] - 222s 569ms/step - loss: 1.9039 - acc: 0.3588 - val_loss: 1.6461 - val_acc: 0.4542
# Epoch 2/30
# 390/390 [==============================] - 210s 537ms/step - loss: 1.5759 - acc: 0.4784 - val_loss: 1.5701 - val_acc: 0.4897
# Epoch 3/30
# 390/390 [==============================] - 210s 538ms/step - loss: 1.4336 - acc: 0.5348 - val_loss: 1.3732 - val_acc: 0.5590
# Epoch 4/30
# 390/390 [==============================] - 210s 539ms/step - loss: 1.3230 - acc: 0.5745 - val_loss: 1.3326 - val_acc: 0.5753
# Epoch 5/30
# 390/390 [==============================] - 209s 537ms/step - loss: 1.2250 - acc: 0.6140 - val_loss: 1.2326 - val_acc: 0.6079
# Epoch 6/30
# 390/390 [==============================] - 209s 535ms/step - loss: 1.1527 - acc: 0.6426 - val_loss: 1.2177 - val_acc: 0.6167
# Epoch 7/30
# 390/390 [==============================] - 209s 536ms/step - loss: 1.0865 - acc: 0.6642 - val_loss: 1.2165 - val_acc: 0.6208
# Epoch 8/30
# 390/390 [==============================] - 209s 535ms/step - loss: 1.0302 - acc: 0.6845 - val_loss: 1.1812 - val_acc: 0.6379
# Epoch 9/30
# 390/390 [==============================] - 209s 536ms/step - loss: 0.9778 - acc: 0.7027 - val_loss: 1.1113 - val_acc: 0.6590
# Epoch 10/30
# 390/390 [==============================] - 209s 535ms/step - loss: 0.9378 - acc: 0.7179 - val_loss: 1.0706 - val_acc: 0.6786
# Epoch 11/30
# 390/390 [==============================] - 209s 537ms/step - loss: 0.8967 - acc: 0.7330 - val_loss: 0.9931 - val_acc: 0.6991
# Epoch 12/30
# 390/390 [==============================] - 209s 535ms/step - loss: 0.8593 - acc: 0.7473 - val_loss: 0.9903 - val_acc: 0.7052
# Epoch 13/30
# 390/390 [==============================] - 209s 536ms/step - loss: 0.8265 - acc: 0.7592 - val_loss: 0.9392 - val_acc: 0.7195
# Epoch 14/30
# 390/390 [==============================] - 209s 537ms/step - loss: 0.7965 - acc: 0.7669 - val_loss: 1.0764 - val_acc: 0.6814
# Epoch 15/30
# 390/390 [==============================] - 209s 536ms/step - loss: 0.7636 - acc: 0.7802 - val_loss: 1.0528 - val_acc: 0.6891
# Epoch 16/30
# 390/390 [==============================] - 209s 536ms/step - loss: 0.7355 - acc: 0.7913 - val_loss: 0.9681 - val_acc: 0.7148
# Epoch 17/30
# 390/390 [==============================] - 209s 537ms/step - loss: 0.7096 - acc: 0.8002 - val_loss: 0.9360 - val_acc: 0.7283
# Epoch 18/30
# 390/390 [==============================] - 209s 536ms/step - loss: 0.6844 - acc: 0.8066 - val_loss: 0.8722 - val_acc: 0.7481
# Epoch 19/30
# 390/390 [==============================] - 209s 536ms/step - loss: 0.6648 - acc: 0.8146 - val_loss: 0.9650 - val_acc: 0.7212
# Epoch 20/30
# 390/390 [==============================] - 209s 535ms/step - loss: 0.6382 - acc: 0.8232 - val_loss: 0.8958 - val_acc: 0.7422
# Epoch 21/30
# 390/390 [==============================] - 209s 535ms/step - loss: 0.6133 - acc: 0.8350 - val_loss: 0.9349 - val_acc: 0.7282
# Epoch 22/30
# 390/390 [==============================] - 209s 537ms/step - loss: 0.5893 - acc: 0.8432 - val_loss: 0.9260 - val_acc: 0.7423
# Epoch 23/30
# 390/390 [==============================] - 209s 536ms/step - loss: 0.5713 - acc: 0.8471 - val_loss: 0.8955 - val_acc: 0.7465
# Epoch 24/30
# 390/390 [==============================] - 209s 536ms/step - loss: 0.5509 - acc: 0.8556 - val_loss: 0.8106 - val_acc: 0.7733
# Epoch 25/30
# 390/390 [==============================] - 209s 537ms/step - loss: 0.5366 - acc: 0.8597 - val_loss: 0.8960 - val_acc: 0.7524
# Epoch 26/30
# 390/390 [==============================] - 209s 537ms/step - loss: 0.5166 - acc: 0.8671 - val_loss: 0.8795 - val_acc: 0.7608
# Epoch 27/30
# 390/390 [==============================] - 209s 536ms/step - loss: 0.4934 - acc: 0.8760 - val_loss: 0.8525 - val_acc: 0.7669
# Epoch 28/30
# 390/390 [==============================] - 209s 536ms/step - loss: 0.4756 - acc: 0.8817 - val_loss: 1.0058 - val_acc: 0.7317
# Epoch 29/30
# 390/390 [==============================] - 209s 536ms/step - loss: 0.4640 - acc: 0.8862 - val_loss: 0.8665 - val_acc: 0.7663
# Epoch 30/30
# 390/390 [==============================] - 209s 536ms/step - loss: 0.4444 - acc: 0.8938 - val_loss: 0.7966 - val_acc: 0.7810
# Model took 6289.30 seconds to train
# Accuracy on test data is: 78.10

# %% [markdown]
# Summary
# ========
#
# The model trained with a validation accuracy of around 71.19%. The model graphs shows a lot of spike. One of the possible reason could be the optimization problem.
#
# This program is to demonstarte functional API . We will work much more on the functional API's in future and work towards making a perfect fit model.
#
# **********   End of Program *************
